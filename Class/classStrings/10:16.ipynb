# %%
import pandas as pd
import numpy as np

# %%
string_1 = "Moses supposes his toeses are roses,"
string_2 = "Moses supposes erroneously."

string_1 + ", but " + string_2
# Out:
# 'Moses supposes his toeses are roses,, but Moses supposes erroneously.'

# %%
string_1 - "Moses"
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# Cell In[3], line 1
#
# ----> 1 string_1 - "Moses"
#
#
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
print(string_1[0:5])
print(string_1[5:])
print(string_2[-12:-1])
# Out:
# Moses
#  supposes his toeses are roses,
# erroneously
# Moses
#  supposes his toeses are roses,
# erroneously

# %%
me = "Kelly"
me_list = ["Kelly"]

print(len(me)) # len of object
print(len(me_list)) # len of list
print(len(me_list[0])) # len of object in list
# Out:
# 5
# 1
# 5
# 5
# 1
# 5

# %%
string_1.lower()
# Out:
# 'moses supposes his toeses are roses,'

# %%
string_3 = "          doot de doo de doo     "
string_3.strip()
# Out:
# 'doot de doo de doo'

# %%
string_4 = "My name is Bond, James Bond."
string_4.find("Bond")
# Out:
# 11

# %%
string_4 = "My name is {}, James {}."
string_4.format("Bond", "Bond")
string_4.format("Franco", "Franco")
# Out:
# 'My name is Franco, James Franco.'

# %%
string_4 = "My name is {lastname}, {firstname} {lastname}."
string_4.format(firstname = "James", lastname = "Baldwin")
# Out:
# 'My name is Baldwin, James Baldwin.'

# %%
def sing_verse_3(number, drink, container):
    number = str(num)
    number_next = str(num-1)
    song = "{number} {container} of {drink} on the wall \n {number} {container} of {drink} \n" #take one down, pass it around, \n {number_next} {container} of {drink} on the wall \n"
    song = song.format(number = number, drink = drink, container = container)

    return song

# %%
sing_verse_3(10, "beer", "bottles")
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# Cell In[59], line 1
#
# ----> 1 sing_verse_3(10, "beer", "bottles")
#
#
#
# Cell In[58], line 2, in sing_verse_3(number, drink, container)
#
#       1 def sing_verse_3(number, drink, container):
#
# ----> 2     number = str(num)
#
#       3     number_next = str(num-1)
#
#       4     song = "{number} {container} of {drink} on the wall \n {number} {container} of {drink} \n" #take one down, pass it around, \n {number_next} {container} of {drink} on the wall \n"
#
#
#
# NameError: name 'num' is not defined

# %%
moses_string = "Moses supposes his toeses are roses, but Moses supposes erroneously.  Moses he knowses his toeses aren't roses, as Moses supposes his toeses to be."

# %%
import re
re.findall(r"[\w]oses", moses_string)
# Out:
# ['Moses',
#  'poses',
#  'roses',
#  'Moses',
#  'poses',
#  'Moses',
#  'roses',
#  'Moses',
#  'poses']

# %%
nursery_rhyme = "Peter Piper picked a peck of pickled peppers, A peck of pickled peppers Peter Piper picked; If Peter Piper picked a peck of pickled peppers, Where’s the peck of pickled peppers Peter Piper picked?"

# %%
my_list = re.split(r"\s", nursery_rhyme)
list(map(lambda x: re.findall(r"^[pP]", x), my_list))
# Out:
# [['P'],
#  ['P'],
#  ['p'],
#  [],
#  ['p'],
#  [],
#  ['p'],
#  ['p'],
#  [],
#  ['p'],
#  [],
#  ['p'],
#  ['p'],
#  ['P'],
#  ['P'],
#  ['p'],
#  [],
#  ['P'],
#  ['P'],
#  ['p'],
#  [],
#  ['p'],
#  [],
#  ['p'],
#  ['p'],
#  [],
#  [],
#  ['p'],
#  [],
#  ['p'],
#  ['p'],
#  ['P'],
#  ['P'],
#  ['p']]

# %%
re.findall(r"[pP]\w*", nursery_rhyme)
# Out:
# ['Peter',
#  'Piper',
#  'picked',
#  'peck',
#  'pickled',
#  'peppers',
#  'peck',
#  'pickled',
#  'peppers',
#  'Peter',
#  'Piper',
#  'picked',
#  'Peter',
#  'Piper',
#  'picked',
#  'peck',
#  'pickled',
#  'peppers',
#  'peck',
#  'pickled',
#  'peppers',
#  'Peter',
#  'Piper',
#  'picked']

# %%
re.findall(r"\w*oe?ses",moses_string)
# Out:
# ['Moses',
#  'supposes',
#  'toeses',
#  'roses',
#  'Moses',
#  'supposes',
#  'Moses',
#  'toeses',
#  'roses',
#  'Moses',
#  'supposes',
#  'toeses']
